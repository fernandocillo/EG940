# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandocillo/EG940/blob/main/EG940_ouvir_senoide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import Audio

# %% [markdown]
# $$x[n] = x(nT_S)$$
# $$x(t)=cos(2\pi f_0t)$$
# $$x[n]=cos(2\pi f_0nT_S)$$

# %%
fs=44100
Ts=1/fs
f0=440
n=np.arange(44100*5) #número de amostras

x1n = np.cos(2 * np.pi * f0 * n * Ts)* 0.1
x2n = np.cos(2 * np.pi * 2*f0 * n * Ts)* 0.1
xn = x1n + x2n

#x_random = np.random.randn(len(n)) * 0.1

# %%
Audio(data=xn, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
